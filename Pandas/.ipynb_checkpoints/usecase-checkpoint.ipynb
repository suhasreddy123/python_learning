# %%
import pandas as pd

# %%
df=pd.read_csv("/home/ramesh/Documents/results.csv")

# %%
df
# Out:
#              date             home_team             away_team  home_score  \
# 0      1872-11-30              Scotland               England           0
# 1      1873-03-08               England              Scotland           4
# 2      1874-03-07              Scotland               England           2
# 3      1875-03-06               England              Scotland           2
# 4      1876-03-04              Scotland               England           3
# 5      1876-03-25              Scotland                 Wales           4
# 6      1877-03-03               England              Scotland           1
# 7      1877-03-05                 Wales              Scotland           0
# 8      1878-03-02              Scotland               England           7
# 9      1878-03-23              Scotland                 Wales           9
# 10     1879-01-18               England                 Wales           2
# 11     1879-04-05               England              Scotland           5
# ...

# %%
df["home_team_wins"]=df.home_score > df.away_score

# %%
df.home_team_wins
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
# 6        False
# 7        False
# 8         True
# 9         True
# 10        True
# 11        True
# 12       False
# 13        True
# 14       False
# 15        True
# 16       False
# 17       False
# 18       False
# 19       False
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 38729     True
# 38730    False
# 38731    False
# 38732    False
# 38733     True
# 38734    False
# 38735    False
# 38736    False
# 38737    False
# 38738    False
# 38739    False
# 38740    False
# 38741     True
# 38742    False
# 38743    False
# 38744    False
# 38745    False
# 38746    False
# 38747     True
# 38748    False
# 38749    False
# 38750    False
# 38751     True
# 38752     True
# 38753    False
# 38754    False
# 38755    False
# ...

# %%
df["away_team_wins"]=df.home_score < df.away_score

# %%
df.away_team_wins
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-214f620e2910> in <module>()
# ----> 1 df.away_team_wins
#
# /home/ramesh/PycharmProjects/test/venv/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'away_team_wins'

# %%
df["home_team_wins"]=df.home_score > df.away_score
df["away_team_wins"]=df.home_score < df.away_score
df["Team_draws"]=df.home_score == df.away_score

# %%
df.home_team_wins
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
# 6        False
# 7        False
# 8         True
# 9         True
# 10        True
# 11        True
# 12       False
# 13        True
# 14       False
# 15        True
# 16       False
# 17       False
# 18       False
# 19       False
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 38729     True
# 38730    False
# 38731    False
# 38732    False
# 38733     True
# 38734    False
# 38735    False
# 38736    False
# 38737    False
# 38738    False
# 38739    False
# 38740    False
# 38741     True
# 38742    False
# 38743    False
# 38744    False
# 38745    False
# 38746    False
# 38747     True
# 38748    False
# 38749    False
# 38750    False
# 38751     True
# 38752     True
# 38753    False
# 38754    False
# 38755    False
# ...

# %%
df.away_team_wins
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# 7         True
# 8        False
# 9        False
# 10       False
# 11       False
# 12        True
# 13       False
# 14        True
# 15       False
# 16        True
# 17        True
# 18        True
# 19        True
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26        True
# 27        True
# 28       False
# 29        True
#          ...
# 38729    False
# 38730     True
# 38731     True
# 38732     True
# 38733    False
# 38734    False
# 38735     True
# 38736     True
# 38737    False
# 38738    False
# 38739     True
# 38740     True
# 38741    False
# 38742    False
# 38743    False
# 38744     True
# 38745    False
# 38746     True
# 38747    False
# 38748     True
# 38749    False
# 38750    False
# 38751    False
# 38752    False
# 38753    False
# 38754    False
# 38755    False
# ...

# %%
df.Team_draws
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28        True
# 29       False
#          ...
# 38729    False
# 38730    False
# 38731    False
# 38732    False
# 38733    False
# 38734     True
# 38735    False
# 38736    False
# 38737     True
# 38738     True
# 38739    False
# 38740    False
# 38741    False
# 38742     True
# 38743     True
# 38744    False
# 38745     True
# 38746    False
# 38747    False
# 38748    False
# 38749     True
# 38750     True
# 38751    False
# 38752    False
# 38753     True
# 38754     True
# 38755     True
# ...

# %%
a=df.groupby("country").home_team_wins.sum()

# %%
a
# Out:
# country
# Afghanistan                   2.0
# Albania                      51.0
# Algeria                     118.0
# Andorra                       4.0
# Angola                       79.0
# Anguilla                      0.0
# Antigua and Barbuda          47.0
# Argentina                   265.0
# Armenia                      22.0
# Aruba                        17.0
# Australia                   152.0
# Austria                     219.0
# Azerbaijan                   22.0
# Bahamas                       3.0
# Bahrain                      93.0
# Bangladesh                   44.0
# Barbados                     57.0
# Belarus                      30.0
# Belgian Congo                 0.0
# Belgium                     194.0
# Belize                        5.0
# Benin                        33.0
# Bermuda                      30.0
# Bhutan                        4.0
# Bohemia                       1.0
# Bohemia and Moravia           1.0
# Bolivia                      92.0
# ...

# %%
# %matplotlib inline
a.plot(kind="bar")

# %%
df
# Out:
#              date             home_team             away_team  home_score  \
# 0      1872-11-30              Scotland               England           0
# 1      1873-03-08               England              Scotland           4
# 2      1874-03-07              Scotland               England           2
# 3      1875-03-06               England              Scotland           2
# 4      1876-03-04              Scotland               England           3
# 5      1876-03-25              Scotland                 Wales           4
# 6      1877-03-03               England              Scotland           1
# 7      1877-03-05                 Wales              Scotland           0
# 8      1878-03-02              Scotland               England           7
# 9      1878-03-23              Scotland                 Wales           9
# 10     1879-01-18               England                 Wales           2
# 11     1879-04-05               England              Scotland           5
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['Date1'] = df['date'].dt.strftime('%Y')

# %%
b=df.groupby("Date1").home_team_wins.sum()

# %%
b
# Out:
# Date1
# 1872      0.0
# 1873      1.0
# 1874      1.0
# 1875      0.0
# 1876      2.0
# 1877      0.0
# 1878      2.0
# 1879      2.0
# 1880      2.0
# 1881      0.0
# 1882      4.0
# 1883      2.0
# 1884      3.0
# 1885      2.0
# 1886      3.0
# 1887      4.0
# 1888      3.0
# 1889      3.0
# 1890      2.0
# 1891      4.0
# 1892      1.0
# 1893      4.0
# 1894      2.0
# 1895      3.0
# 1896      3.0
# 1897      4.0
# 1898      1.0
# 1899      5.0
# 1900      3.0
# 1901      3.0
#         ...
# 1989    277.0
# 1990    202.0
# 1991    210.0
# 1992    267.0
# 1993    342.0
# 1994    274.0
# 1995    325.0
# 1996    421.0
# 1997    437.0
# 1998    335.0
# 1999    348.0
# 2000    522.0
# 2001    471.0
# 2002    332.0
# 2003    452.0
# 2004    481.0
# 2005    370.0
# 2006    396.0
# 2007    453.0
# 2008    515.0
# 2009    405.0
# 2010    379.0
# 2011    501.0
# 2012    482.0
# 2013    459.0
# 2014    379.0
# 2015    445.0
# 2016    424.0
# 2017    397.0
# 2018      1.0
# ...

# %%
b.plot(kind="bar")

# %%
df
# Out:
#             date             home_team             away_team  home_score  \
# 0     1872-11-30              Scotland               England           0
# 1     1873-03-08               England              Scotland           4
# 2     1874-03-07              Scotland               England           2
# 3     1875-03-06               England              Scotland           2
# 4     1876-03-04              Scotland               England           3
# 5     1876-03-25              Scotland                 Wales           4
# 6     1877-03-03               England              Scotland           1
# 7     1877-03-05                 Wales              Scotland           0
# 8     1878-03-02              Scotland               England           7
# 9     1878-03-23              Scotland                 Wales           9
# 10    1879-01-18               England                 Wales           2
# 11    1879-04-05               England              Scotland           5
# ...

# %%
s=pd.crosstab(df.country,df.Date1)

# %%
s
# Out:
# Date1           1872  1873  1874  1875  1876  1877  1878  1879  1880  1881  \
# home_team_wins
# False              1     0     0     1     0     2     0     1     1     3
# True               0     1     1     0     2     0     2     2     2     0
#
# Date1           ...   2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# home_team_wins  ...
# False           ...    445   460   548   509   493   450   497   455   464
# True            ...    405   379   501   482   459   379   445   424   397
#
# Date1           2018
# home_team_wins
# False              6
# True               1
#
# [2 rows x 147 columns]

# %%
s
# Out:
# Date1           1872  1873  1874  1875  1876  1877  1878  1879  1880  1881  \
# home_team_wins
# False              1     0     0     1     0     2     0     1     1     3
# True               0     1     1     0     2     0     2     2     2     0
#
# Date1           ...   2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# home_team_wins  ...
# False           ...    445   460   548   509   493   450   497   455   464
# True            ...    405   379   501   482   459   379   445   424   397
#
# Date1           2018
# home_team_wins
# False              6
# True               1
#
# [2 rows x 147 columns]

# %%
s
# Out:
# Date1                     1872  1873  1874  1875  1876  1877  1878  1879  \
# country
# Afghanistan                  0     0     0     0     0     0     0     0
# Albania                      0     0     0     0     0     0     0     0
# Algeria                      0     0     0     0     0     0     0     0
# Andorra                      0     0     0     0     0     0     0     0
# Angola                       0     0     0     0     0     0     0     0
# Anguilla                     0     0     0     0     0     0     0     0
# Antigua and Barbuda          0     0     0     0     0     0     0     0
# Argentina                    0     0     0     0     0     0     0     0
# Armenia                      0     0     0     0     0     0     0     0
# Aruba                        0     0     0     0     0     0     0     0
# Australia                    0     0     0     0     0     0     0     0
# Austria                      0     0     0     0     0     0     0     0
# ...
